# %%
from random import uniform
from matplotlib import pyplot as plt

# %%
def random():
    return uniform(-1000, 1000) > 0

# %%
x = list(range(2))
y = [0 for i in range(2)]

for i in range(1000):
    if (random()):
        y [0] +=1
    else:
        y [1] +=1


plt.plot(x, y)
plt.show()

# %%
def uniformRange(a, b):
    pool = list(range(a, b+1))
    #print(pool)
    while (len(pool) > 1):
        newpool = []
        while (len(newpool) < 1):
            newpool = [i for i in pool if random()]
        pool = newpool
        #print(newpool)
    return pool[0]

# %%
for i in range(10):
    print(uniformRange(0, 10))
# Out:
# 1
# 5
# 4
# 3
# 5
# 7
# 3
# 3
# 7
# 3

# %%
x = list(range(10))
y = [0 for i in range(10)]

for i in range(100000):
    y[uniformRange(0, 9)] +=1

fig, ax = plt.subplots(figsize = (10, 10))
plt.plot(x, y)

plt.ylim([0, 20000])

plt.show()
